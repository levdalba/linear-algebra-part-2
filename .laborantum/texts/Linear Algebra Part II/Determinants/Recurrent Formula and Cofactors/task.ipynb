# %%
import numpy as np
import json_tricks

# %%
answer = {
    'task1': {
        'C1': np.array([
            ### YOUR CODE HERE ###
            1.0, -0.0, 0.0, -2.0
        ]).T,
        'det': (
            ### YOUR CODE HERE ###
            -1
        )
    },
    'task2': {
        'C1': np.array(
            ### YOUR CODE HERE ###
            [1.0, -1.0, 0.0, -1.0]
        ),
        'det': (
            ### YOUR CODE HERE ###
            -1
        )
    }
}

# %%
json_tricks.dump(answer, '.answer.json')
# Out:
# '{"task1": {"C1": {"__ndarray__": [[1], [0], [0], [-2]], "dtype": "int64", "shape": [4, 1], "Corder": true}, "det": -1.0}, "task2": {"C1": {"__ndarray__": [[1, -1, 0, -1]], "dtype": "int64", "shape": [1, 4], "Corder": true}, "det": -1.0}}'
