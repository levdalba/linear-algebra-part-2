# %%
import numpy as np
import json_tricks

# %%
answer = {
    'task1': {
        '||x||': float(
            0.5773502691896257
        ),
        '||x^2||': float(
            0.4472135954999579
        ),
        '<x, x^2>': float(
            0.25
        ),
        'cos': float(
            0.9682458365518544
        ),
    },
    'task2': {
        '||sin x||': float(
            0.5221835341080563
        ),
        '||cos x||': float(
            0.8528331353239158
        ),
        '<sin x, cos x>': float(
            0.3540367091367856
        ),
        'cos': float(
            0.794988884229138
        ),
    },
    'task3': {
        '||exp x||': float(
            1.7873242709327608
        ),
        '||sin x||': float(
            0.5221835341080563
        ),
        '<exp x, sin x>': float(
            0.9093306736314786
        ),
        'cos': float(
            0.9743058605971802
        ),
    },
}

json_tricks.dump(answer, '.answer.json')
